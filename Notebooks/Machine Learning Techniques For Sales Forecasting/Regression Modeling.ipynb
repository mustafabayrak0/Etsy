# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from xgboost.sklearn import XGBRegressor

import keras
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import Adam 
from keras.callbacks import EarlyStopping
from keras.utils import np_utils
from keras.layers import LSTM
from sklearn.model_selection import KFold, cross_val_score, train_test_split

import pickle
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.ensemble import RandomForestRegressor

# %%
model_df = pd.read_csv('../../Datasets/Bouletta/model_df.csv')

# %%
model_df
# Out:
#           date  Total Profits  sales_diff    lag_1    lag_2    lag_3    lag_4  \
# 0   2021-02-01        1523.74    -2724.55    33.46 -1743.50  2319.86  1627.87
# 1   2021-03-01        2377.14      853.40 -2724.55    33.46 -1743.50  2319.86
# 2   2021-04-01        2426.04       48.90   853.40 -2724.55    33.46 -1743.50
# 3   2021-05-01        3420.63      994.59    48.90   853.40 -2724.55    33.46
# 4   2021-06-01        4390.43      969.80   994.59    48.90   853.40 -2724.55
# 5   2021-07-01        4265.53     -124.90   969.80   994.59    48.90   853.40
# 6   2021-08-01        6587.68     2322.15  -124.90   969.80   994.59    48.90
# 7   2021-09-01        5932.61     -655.07  2322.15  -124.90   969.80   994.59
# 8   2021-10-01        4582.69    -1349.92  -655.07  2322.15  -124.90   969.80
# 9   2021-11-01        4860.97      278.28 -1349.92  -655.07  2322.15  -124.90
# 10  2021-12-01        6170.78     1309.81   278.28 -1349.92  -655.07  2322.15
# 11  2022-01-01        3581.39    -2589.39  1309.81   278.28 -1349.92  -655.07
# 12  2022-02-01        3377.72     -203.67 -2589.39  1309.81   278.28 -1349.92
# 13  2022-03-01        4673.31     1295.59  -203.67 -2589.39  1309.81   278.28
# 14  2022-04-01        3368.37    -1304.94  1295.59  -203.67 -2589.39  1309.81
# 15  2022-05-01        2777.34     -591.03 -1304.94  1295.59  -203.67 -2589.39
# 16  2022-06-01        3623.00      845.66  -591.03 -1304.94  1295.59  -203.67
# 17  2022-07-01        3038.96     -584.04   845.66  -591.03 -1304.94  1295.59
# 18  2022-08-01        2468.36     -570.60  -584.04   845.66  -591.03 -1304.94
# 19  2022-09-01        2160.93     -307.43  -570.60  -584.04   845.66  -591.03
# 20  2022-10-01        2199.47       38.54  -307.43  -570.60  -584.04   845.66
# 21  2022-11-01        1226.17     -973.30    38.54  -307.43  -570.60  -584.04
# 22  2022-12-01        3060.06     1833.89  -973.30    38.54  -307.43  -570.60
#
#       lag_5    lag_6    lag_7    lag_8    lag_9   lag_10   lag_11   lag_12
# 0   -332.04   -22.29  -531.44  -361.84  1146.64  1124.21   -52.16  -322.09
# 1   1627.87  -332.04   -22.29  -531.44  -361.84  1146.64  1124.21   -52.16
# 2   2319.86  1627.87  -332.04   -22.29  -531.44  -361.84  1146.64  1124.21
# 3  -1743.50  2319.86  1627.87  -332.04   -22.29  -531.44  -361.84  1146.64
# 4     33.46 -1743.50  2319.86  1627.87  -332.04   -22.29  -531.44  -361.84
# 5  -2724.55    33.46 -1743.50  2319.86  1627.87  -332.04   -22.29  -531.44
# 6    853.40 -2724.55    33.46 -1743.50  2319.86  1627.87  -332.04   -22.29
# 7     48.90   853.40 -2724.55    33.46 -1743.50  2319.86  1627.87  -332.04
# 8    994.59    48.90   853.40 -2724.55    33.46 -1743.50  2319.86  1627.87
# 9    969.80   994.59    48.90   853.40 -2724.55    33.46 -1743.50  2319.86
# 10  -124.90   969.80   994.59    48.90   853.40 -2724.55    33.46 -1743.50
# 11  2322.15  -124.90   969.80   994.59    48.90   853.40 -2724.55    33.46
# 12  -655.07  2322.15  -124.90   969.80   994.59    48.90   853.40 -2724.55
# 13 -1349.92  -655.07  2322.15  -124.90   969.80   994.59    48.90   853.40
# 14   278.28 -1349.92  -655.07  2322.15  -124.90   969.80   994.59    48.90
# 15  1309.81   278.28 -1349.92  -655.07  2322.15  -124.90   969.80   994.59
# 16 -2589.39  1309.81   278.28 -1349.92  -655.07  2322.15  -124.90   969.80
# 17  -203.67 -2589.39  1309.81   278.28 -1349.92  -655.07  2322.15  -124.90
# 18  1295.59  -203.67 -2589.39  1309.81   278.28 -1349.92  -655.07  2322.15
# 19 -1304.94  1295.59  -203.67 -2589.39  1309.81   278.28 -1349.92  -655.07
# 20  -591.03 -1304.94  1295.59  -203.67 -2589.39  1309.81   278.28 -1349.92
# 21   845.66  -591.03 -1304.94  1295.59  -203.67 -2589.39  1309.81   278.28
# 22  -584.04   845.66  -591.03 -1304.94  1295.59  -203.67 -2589.39  1309.81

# %%
def tts(data):
    data = data.drop(['Total Profits','date'],axis=1)
    train, test = data[0:-12].values, data[-12:].values
    
    return train, test

train, test = tts(model_df)

# %%
train.shape
# Out:
# (11, 13)

# %%
test.shape
# Out:
# (12, 13)

# %%
def scale_data(train_set, test_set):
    #apply Min Max Scaler
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler = scaler.fit(train_set)
    
    # reshape training set
    train_set = train_set.reshape(train_set.shape[0], train_set.shape[1])
    train_set_scaled = scaler.transform(train_set)
    
    # reshape test set
    test_set = test_set.reshape(test_set.shape[0], test_set.shape[1])
    test_set_scaled = scaler.transform(test_set)
    
    X_train, y_train = train_set_scaled[:, 1:], train_set_scaled[:, 0:1].ravel()
    X_test, y_test = test_set_scaled[:, 1:], test_set_scaled[:, 0:1].ravel()
    
    return X_train, y_train, X_test, y_test, scaler

X_train, y_train, X_test, y_test, scaler_object = scale_data(train, test)

# %%
y_train.shape
# Out:
# (11,)

# %%
def undo_scaling(y_pred, x_test, scaler_obj, lstm=False):  
    #reshape y_pred
    y_pred = y_pred.reshape(y_pred.shape[0], 1, 1)
    
    if not lstm:
        x_test = x_test.reshape(x_test.shape[0], 1, x_test.shape[1])
    
    #rebuild test set for inverse transform
    pred_test_set = []
    for index in range(0,len(y_pred)):
        pred_test_set.append(np.concatenate([y_pred[index],x_test[index]],axis=1))
        
    #reshape pred_test_set
    pred_test_set = np.array(pred_test_set)
    pred_test_set = pred_test_set.reshape(pred_test_set.shape[0], pred_test_set.shape[2])
    
    #inverse transform
    pred_test_set_inverted = scaler_obj.inverse_transform(pred_test_set)
    
    return pred_test_set_inverted

# %%
def load_original_df():
    #load in original dataframe without scaling applied
    original_df = pd.read_csv("../../Datasets/Bouletta/train.csv")
    original_df.date = original_df.date.apply(lambda x: str(x)[:-3])
    original_df = original_df.groupby('date')['Total Profits'].sum().reset_index()
    original_df.date = pd.to_datetime(original_df.date)
    return original_df

# %%
def predict_df(unscaled_predictions, original_df):
    #create dataframe that shows the predicted sales
    result_list = []
    sales_dates = list(original_df[-13:].date)
    act_sales = list(original_df[-13:]["Total Profits"])
    
    for index in range(0,len(unscaled_predictions)):
        result_dict = {}
        result_dict['pred_value'] = int(unscaled_predictions[index][0] + act_sales[index])
        result_dict['date'] = sales_dates[index+1]
        result_list.append(result_dict)
        
    df_result = pd.DataFrame(result_list)
    
    return df_result

# %%
model_scores = {}

def get_scores(unscaled_df, original_df, model_name):
    rmse = np.sqrt(mean_squared_error(original_df["Total Profits"][-12:], unscaled_df.pred_value[-12:]))
    mae = mean_absolute_error(original_df["Total Profits"][-12:], unscaled_df.pred_value[-12:])
    r2 = r2_score(original_df["Total Profits"][-12:], unscaled_df.pred_value[-12:])
    model_scores[model_name] = [rmse, mae, r2]

    print(f"RMSE: {rmse}")
    print(f"MAE: {mae}")
    print(f"R2 Score: {r2}")

# %%
def plot_results(results, original_df, model_name):

    fig, ax = plt.subplots(figsize=(15,5))
    sns.lineplot(original_df.date, original_df["Total Profits"], data=original_df, ax=ax, 
                 label='Original', color='mediumblue')
    sns.lineplot(results.date, results.pred_value, data=results, ax=ax, 
                 label='Predicted', color='Red')
    
    ax.set(xlabel = "date",
           ylabel = "Total Profits",
           title = f"{model_name} Sales Forecasting Prediction")
    
    ax.legend()
    
    sns.despine()
    
    plt.savefig(f'../../Outputs/{model_name}_forecast.png')

# %%
def run_model(train_data, test_data, model, model_name):
    
    X_train, y_train, X_test, y_test, scaler_object = scale_data(train_data, test_data)
    
    mod = model
    mod.fit(X_train, y_train)
    predictions = mod.predict(X_test)
    
    # Undo scaling to compare predictions against original data
    original_df = load_original_df()
    unscaled = undo_scaling(predictions, X_test, scaler_object)
    unscaled_df = predict_df(unscaled, original_df)
      
    get_scores(unscaled_df, original_df, model_name)
    
    plot_results(unscaled_df, original_df, model_name)

# %%
run_model(train, test, LinearRegression(), 'LinearRegression')
# Out:
# RMSE: 4999.129743503697
# MAE: 3839.9083333333333
# R2 Score: -33.80405230146087
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
run_model(train, test, RandomForestRegressor(n_estimators=100, max_depth=20), 
          'RandomForest')
# Out:
# RMSE: 1314.4777178471556
# MAE: 1020.2216666666667
# R2 Score: -1.4062871585885555
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
run_model(train, test, XGBRegressor( n_estimators=100, 
                                    learning_rate=0.2, 
                                    objective='reg:squarederror'), 'XGBoost')
# Out:
# RMSE: 1757.0210914262432
# MAE: 1493.7666666666667
# R2 Score: -3.2992722328125312
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
def lstm_model(train_data, test_data):
    
    X_train, y_train, X_test, y_test, scaler_object = scale_data(train_data, test_data)
    
    X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
    X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])
   
    model = Sequential()
    model.add(LSTM(4, batch_input_shape=(1, X_train.shape[1], X_train.shape[2]), 
                   stateful=True))
    model.add(Dense(1))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    model.fit(X_train, y_train, epochs=200, batch_size=1, verbose=1, 
              shuffle=False)
    predictions = model.predict(X_test,batch_size=1)
    
    original_df = load_original_df()
    unscaled = undo_scaling(predictions, X_test, scaler_object, lstm=True)
    unscaled_df = predict_df(unscaled, original_df)
    
    get_scores(unscaled_df, original_df, 'LSTM')
    
    plot_results(unscaled_df, original_df, 'LSTM')

# %%
lstm_model(train, test)
# Out:
# Epoch 1/200
# 11/11 [==============================] - 3s 3ms/step - loss: 0.3012
# Epoch 2/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2995
# Epoch 3/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2977
# Epoch 4/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2959
# Epoch 5/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2943
# Epoch 6/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2928
# Epoch 7/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2913
# Epoch 8/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2899
# Epoch 9/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2885
# Epoch 10/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2872
# Epoch 11/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2859
# Epoch 12/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2845
# Epoch 13/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2832
# Epoch 14/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2818
# Epoch 15/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2803
# Epoch 16/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2789
# Epoch 17/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2773
# Epoch 18/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2757
# Epoch 19/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2741
# Epoch 20/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2723
# Epoch 21/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2705
# Epoch 22/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2685
# Epoch 23/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2665
# Epoch 24/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2643
# Epoch 25/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2621
# Epoch 26/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2597
# Epoch 27/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2571
# Epoch 28/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2545
# Epoch 29/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2517
# Epoch 30/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2487
# Epoch 31/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2456
# Epoch 32/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2424
# Epoch 33/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2390
# Epoch 34/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2354
# Epoch 35/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2317
# Epoch 36/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2278
# Epoch 37/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2238
# Epoch 38/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2196
# Epoch 39/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2153
# Epoch 40/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2108
# Epoch 41/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2063
# Epoch 42/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2016
# Epoch 43/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1968
# Epoch 44/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1919
# Epoch 45/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1869
# Epoch 46/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1819
# Epoch 47/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1768
# Epoch 48/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1716
# Epoch 49/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1665
# Epoch 50/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1614
# Epoch 51/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1563
# Epoch 52/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1512
# Epoch 53/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1461
# Epoch 54/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1411
# Epoch 55/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1362
# Epoch 56/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1313
# Epoch 57/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1265
# Epoch 58/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1218
# Epoch 59/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1171
# Epoch 60/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1125
# Epoch 61/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1079
# Epoch 62/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1035
# Epoch 63/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0990
# Epoch 64/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0947
# Epoch 65/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0904
# Epoch 66/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0861
# Epoch 67/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0820
# Epoch 68/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0779
# Epoch 69/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0739
# Epoch 70/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0699
# Epoch 71/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0661
# Epoch 72/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0624
# Epoch 73/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0588
# Epoch 74/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0552
# Epoch 75/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0519
# Epoch 76/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0486
# Epoch 77/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0455
# Epoch 78/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0425
# Epoch 79/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0396
# Epoch 80/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0369
# Epoch 81/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0343
# Epoch 82/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0318
# Epoch 83/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0295
# Epoch 84/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0273
# Epoch 85/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0253
# Epoch 86/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0233
# Epoch 87/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0215
# Epoch 88/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0198
# Epoch 89/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0182
# Epoch 90/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0168
# Epoch 91/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0154
# Epoch 92/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0141
# Epoch 93/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 94/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0118
# Epoch 95/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0108
# Epoch 96/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0098
# Epoch 97/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0089
# Epoch 98/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0081
# Epoch 99/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 100/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0067
# Epoch 101/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 102/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0055
# Epoch 103/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0049
# Epoch 104/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 105/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 106/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0036
# Epoch 107/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0032
# Epoch 108/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 109/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 110/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0023
# Epoch 111/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0020
# Epoch 112/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 113/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 114/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 115/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 116/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 117/200
# 11/11 [==============================] - 0s 2ms/step - loss: 9.6671e-04
# Epoch 118/200
# 11/11 [==============================] - 0s 2ms/step - loss: 8.4938e-04
# Epoch 119/200
# 11/11 [==============================] - 0s 2ms/step - loss: 7.4498e-04
# Epoch 120/200
# 11/11 [==============================] - 0s 2ms/step - loss: 6.5227e-04
# Epoch 121/200
# 11/11 [==============================] - 0s 2ms/step - loss: 5.7011e-04
# Epoch 122/200
# 11/11 [==============================] - 0s 2ms/step - loss: 4.9743e-04
# Epoch 123/200
# 11/11 [==============================] - 0s 3ms/step - loss: 4.3327e-04
# Epoch 124/200
# 11/11 [==============================] - 0s 3ms/step - loss: 3.7674e-04
# Epoch 125/200
# 11/11 [==============================] - 0s 3ms/step - loss: 3.2703e-04
# Epoch 126/200
# 11/11 [==============================] - 0s 3ms/step - loss: 2.8341e-04
# Epoch 127/200
# 11/11 [==============================] - 0s 3ms/step - loss: 2.4519e-04
# Epoch 128/200
# 11/11 [==============================] - 0s 2ms/step - loss: 2.1178e-04
# Epoch 129/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8263e-04
# Epoch 130/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5723e-04
# Epoch 131/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.3515e-04
# Epoch 132/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.1600e-04
# Epoch 133/200
# 11/11 [==============================] - 0s 2ms/step - loss: 9.9400e-05
# Epoch 134/200
# 11/11 [==============================] - 0s 2ms/step - loss: 8.5048e-05
# Epoch 135/200
# 11/11 [==============================] - 0s 2ms/step - loss: 7.2660e-05
# Epoch 136/200
# 11/11 [==============================] - 0s 2ms/step - loss: 6.1987e-05
# Epoch 137/200
# 11/11 [==============================] - 0s 3ms/step - loss: 5.2805e-05
# Epoch 138/200
# 11/11 [==============================] - 0s 2ms/step - loss: 4.4921e-05
# Epoch 139/200
# 11/11 [==============================] - 0s 3ms/step - loss: 3.8162e-05
# Epoch 140/200
# 11/11 [==============================] - 0s 3ms/step - loss: 3.2377e-05
# Epoch 141/200
# 11/11 [==============================] - 0s 3ms/step - loss: 2.7432e-05
# Epoch 142/200
# 11/11 [==============================] - 0s 3ms/step - loss: 2.3214e-05
# Epoch 143/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9620e-05
# Epoch 144/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6563e-05
# Epoch 145/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.3965e-05
# Epoch 146/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.1763e-05
# Epoch 147/200
# 11/11 [==============================] - 0s 2ms/step - loss: 9.8969e-06
# Epoch 148/200
# 11/11 [==============================] - 0s 2ms/step - loss: 8.3185e-06
# Epoch 149/200
# 11/11 [==============================] - 0s 2ms/step - loss: 6.9849e-06
# Epoch 150/200
# 11/11 [==============================] - 0s 2ms/step - loss: 5.8596e-06
# Epoch 151/200
# 11/11 [==============================] - 0s 2ms/step - loss: 4.9116e-06
# Epoch 152/200
# 11/11 [==============================] - 0s 2ms/step - loss: 4.1131e-06
# Epoch 153/200
# 11/11 [==============================] - 0s 2ms/step - loss: 3.4417e-06
# Epoch 154/200
# 11/11 [==============================] - 0s 2ms/step - loss: 2.8778e-06
# Epoch 155/200
# 11/11 [==============================] - 0s 2ms/step - loss: 2.4047e-06
# Epoch 156/200
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0080e-06
# Epoch 157/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6757e-06
# Epoch 158/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.3975e-06
# Epoch 159/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.1651e-06
# Epoch 160/200
# 11/11 [==============================] - 0s 2ms/step - loss: 9.7097e-07
# Epoch 161/200
# 11/11 [==============================] - 0s 2ms/step - loss: 8.0875e-07
# Epoch 162/200
# 11/11 [==============================] - 0s 2ms/step - loss: 6.7325e-07
# Epoch 163/200
# 11/11 [==============================] - 0s 2ms/step - loss: 5.6039e-07
# Epoch 164/200
# 11/11 [==============================] - 0s 2ms/step - loss: 4.6641e-07
# Epoch 165/200
# 11/11 [==============================] - 0s 3ms/step - loss: 3.8814e-07
# Epoch 166/200
# 11/11 [==============================] - 0s 2ms/step - loss: 3.2292e-07
# Epoch 167/200
# 11/11 [==============================] - 0s 2ms/step - loss: 2.6856e-07
# Epoch 168/200
# 11/11 [==============================] - 0s 2ms/step - loss: 2.2342e-07
# Epoch 169/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.8579e-07
# Epoch 170/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5453e-07
# Epoch 171/200
# 11/11 [==============================] - 0s 3ms/step - loss: 1.2856e-07
# Epoch 172/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.0696e-07
# Epoch 173/200
# 11/11 [==============================] - 0s 2ms/step - loss: 8.9017e-08
# Epoch 174/200
# 11/11 [==============================] - 0s 2ms/step - loss: 7.4100e-08
# Epoch 175/200
# 11/11 [==============================] - 0s 2ms/step - loss: 6.1690e-08
# Epoch 176/200
# 11/11 [==============================] - 0s 2ms/step - loss: 5.1357e-08
# Epoch 177/200
# 11/11 [==============================] - 0s 3ms/step - loss: 4.2813e-08
# Epoch 178/200
# 11/11 [==============================] - 0s 2ms/step - loss: 3.5653e-08
# Epoch 179/200
# 11/11 [==============================] - 0s 2ms/step - loss: 2.9716e-08
# Epoch 180/200
# 11/11 [==============================] - 0s 2ms/step - loss: 2.4743e-08
# Epoch 181/200
# 11/11 [==============================] - 0s 2ms/step - loss: 2.0634e-08
# Epoch 182/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.7212e-08
# Epoch 183/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.4370e-08
# Epoch 184/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.1970e-08
# Epoch 185/200
# 11/11 [==============================] - 0s 2ms/step - loss: 9.9911e-09
# Epoch 186/200
# 11/11 [==============================] - 0s 2ms/step - loss: 8.3407e-09
# Epoch 187/200
# 11/11 [==============================] - 0s 2ms/step - loss: 6.9552e-09
# Epoch 188/200
# 11/11 [==============================] - 0s 2ms/step - loss: 5.8239e-09
# Epoch 189/200
# 11/11 [==============================] - 0s 2ms/step - loss: 4.8585e-09
# Epoch 190/200
# 11/11 [==============================] - 0s 2ms/step - loss: 4.0527e-09
# Epoch 191/200
# 11/11 [==============================] - 0s 2ms/step - loss: 3.3837e-09
# Epoch 192/200
# 11/11 [==============================] - 0s 2ms/step - loss: 2.8285e-09
# Epoch 193/200
# 11/11 [==============================] - 0s 2ms/step - loss: 2.3678e-09
# Epoch 194/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.9776e-09
# Epoch 195/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.6541e-09
# Epoch 196/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.3809e-09
# Epoch 197/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.1542e-09
# Epoch 198/200
# 11/11 [==============================] - 0s 2ms/step - loss: 9.5944e-10
# Epoch 199/200
# 11/11 [==============================] - 0s 2ms/step - loss: 7.9819e-10
# Epoch 200/200
# 11/11 [==============================] - 0s 2ms/step - loss: 6.6613e-10
# 12/12 [==============================] - 0s 2ms/step
# RMSE: 1893.6046416953043
# MAE: 1551.1383333333333
# R2 Score: -3.9936674234272163
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pickle.dump(model_scores, open( "model_scores.p", "wb" ) )
